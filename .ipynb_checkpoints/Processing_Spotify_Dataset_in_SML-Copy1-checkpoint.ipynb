# %% [markdown]
# # Import Library and Dataset

# %%
import matplotlib.pyplot as plt
import matplotlib as pt
import pandas as pd
from sklearn import datasets
from sklearn.svm import SVC
import numpy as np
from sklearn.metrics import accuracy_score
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
url = 'https://raw.githubusercontent.com/Gitroars/BS_FoDS_Project/main/Dataset/Spotify-2000.csv'
df = pd.read_csv(url)
df
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# 1              album rock  2000                     135      79            50
# 2     alternative hip hop  2001                     168      69            66
# 3       alternative metal  2007                     173      96            43
# 4            classic rock  2002                     106      82            58
# ...                   ...   ...                     ...     ...           ...
# 1989      adult standards  1958                      94      21            70
# 1990      adult standards  1958                     175      76            36
# 1991           blues rock  1959                     168      80            53
# 1992                bebop  1959                     174      26            45
# 1993      adult standards  1959                     133      50            49
#
#       Loudness (dB)  Liveness  Valence Length (Duration)  Acousticness  \
# 0               -14        11       68               201            94
# 1               -11        17       81               207            17
# 2                -9         7       52               341             2
# 3                -4         3       37               269             0
# 4                -5        10       87               256             1
# ...             ...       ...      ...               ...           ...
# 1989            -12        11       72               128            84
# 1990             -8        76       95               136            73
# 1991             -9        31       97               162            74
# 1992            -13         7       60               324            54
# 1993            -10        16       83               148            74
#
#       Speechiness  Popularity
# 0               3          71
# 1               7          39
# 2              17          69
# 3               4          76
# 4               3          59
# ...           ...         ...
# 1989            7          63
# 1990            6          69
# 1991            7          74
# 1992            4          65
# 1993            3          56
#
# [1994 rows x 15 columns]

# %% [markdown]
# # DATA MUNGING

# %%
df.info
# Out:
# <bound method DataFrame.info of       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# 1              album rock  2000                     135      79            50
# 2     alternative hip hop  2001                     168      69            66
# 3       alternative metal  2007                     173      96            43
# 4            classic rock  2002                     106      82            58
# ...                   ...   ...                     ...     ...           ...
# 1989      adult standards  1958                      94      21            70
# 1990      adult standards  1958                     175      76            36
# 1991           blues rock  1959                     168      80            53
# 1992                bebop  1959                     174      26            45
# 1993      adult standards  1959                     133      50            49
#
#       Loudness (dB)  Liveness  Valence Length (Duration)  Acousticness  \
# 0               -14        11       68               201            94
# 1               -11        17       81               207            17
# 2                -9         7       52               341             2
# 3                -4         3       37               269             0
# 4                -5        10       87               256             1
# ...             ...       ...      ...               ...           ...
# 1989            -12        11       72               128            84
# 1990             -8        76       95               136            73
# 1991             -9        31       97               162            74
# 1992            -13         7       60               324            54
# 1993            -10        16       83               148            74
#
#       Speechiness  Popularity
# 0               3          71
# 1               7          39
# 2              17          69
# 3               4          76
# 4               3          59
# ...           ...         ...
# 1989            7          63
# 1990            6          69
# 1991            7          74
# 1992            4          65
# 1993            3          56
#
# [1994 rows x 15 columns]>

# %%
df.rename(columns = {'Top Genre':'top_genre'}, inplace = True)

# %%
df.top_genre.value_counts()
# Out:
# album rock           413
# adult standards      123
# dutch pop             88
# alternative rock      86
# dance pop             83
#                     ...
# streektaal             1
# indie anthem-folk      1
# la pop                 1
# ccm                    1
# bebop                  1
# Name: top_genre, Length: 149, dtype: int64

# %%
df.head()
# Out:
#    Index                   Title             Artist            top_genre  \
# 0      1                 Sunrise        Norah Jones      adult standards
# 1      2             Black Night        Deep Purple           album rock
# 2      3          Clint Eastwood           Gorillaz  alternative hip hop
# 3      4           The Pretender       Foo Fighters    alternative metal
# 4      5  Waitin' On A Sunny Day  Bruce Springsteen         classic rock
#
#    Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 0  2004                     157      30            53            -14
# 1  2000                     135      79            50            -11
# 2  2001                     168      69            66             -9
# 3  2007                     173      96            43             -4
# 4  2002                     106      82            58             -5
#
#    Liveness  Valence Length (Duration)  Acousticness  Speechiness  Popularity
# 0        11       68               201            94            3          71
# 1        17       81               207            17            7          39
# 2         7       52               341             2           17          69
# 3         3       37               269             0            4          76
# 4        10       87               256             1            3          59

# %%
df.tail()
# Out:
#       Index             Title                    Artist        top_genre  \
# 1989   1990  Heartbreak Hotel             Elvis Presley  adult standards
# 1990   1991         Hound Dog             Elvis Presley  adult standards
# 1991   1992   Johnny B. Goode               Chuck Berry       blues rock
# 1992   1993         Take Five  The Dave Brubeck Quartet            bebop
# 1993   1994    Blueberry Hill               Fats Domino  adult standards
#
#       Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 1989  1958                      94      21            70            -12
# 1990  1958                     175      76            36             -8
# 1991  1959                     168      80            53             -9
# 1992  1959                     174      26            45            -13
# 1993  1959                     133      50            49            -10
#
#       Liveness  Valence Length (Duration)  Acousticness  Speechiness  \
# 1989        11       72               128            84            7
# 1990        76       95               136            73            6
# 1991        31       97               162            74            7
# 1992         7       60               324            54            4
# 1993        16       83               148            74            3
#
#       Popularity
# 1989          63
# 1990          69
# 1991          74
# 1992          65
# 1993          56

# %%
df.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)       Energy  \
# count  1994.000000  1994.000000             1994.000000  1994.000000
# mean    997.500000  1992.992979              120.215647    59.679539
# std     575.762538    16.116048               28.028096    22.154322
# min       1.000000  1956.000000               37.000000     3.000000
# 25%     499.250000  1979.000000               99.000000    42.000000
# 50%     997.500000  1993.000000              119.000000    61.000000
# 75%    1495.750000  2007.000000              136.000000    78.000000
# max    1994.000000  2019.000000              206.000000   100.000000
#
#        Danceability  Loudness (dB)     Liveness      Valence  Acousticness  \
# count   1994.000000    1994.000000  1994.000000  1994.000000   1994.000000
# mean      53.238215      -9.008526    19.012036    49.408726     28.858074
# std       15.351507       3.647876    16.727378    24.858212     29.011986
# min       10.000000     -27.000000     2.000000     3.000000      0.000000
# 25%       43.000000     -11.000000     9.000000    29.000000      3.000000
# 50%       53.000000      -8.000000    12.000000    47.000000     18.000000
# 75%       64.000000      -6.000000    23.000000    69.750000     50.000000
# max       96.000000      -2.000000    99.000000    99.000000     99.000000
#
#        Speechiness  Popularity
# count  1994.000000  1994.00000
# mean      4.994985    59.52658
# std       4.401566    14.35160
# min       2.000000    11.00000
# 25%       3.000000    49.25000
# 50%       4.000000    62.00000
# 75%       5.000000    71.00000
# max      55.000000   100.00000

# %%
df.isnull().sum()
# Out:
# Index                     0
# Title                     0
# Artist                    0
# top_genre                 0
# Year                      0
# Beats Per Minute (BPM)    0
# Energy                    0
# Danceability              0
# Loudness (dB)             0
# Liveness                  0
# Valence                   0
# Length (Duration)         0
# Acousticness              0
# Speechiness               0
# Popularity                0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df2 = df.dropna()

# %%
print(df2.dtypes)
print(df.dtypes)
# Out:
# Index                      int64
# Title                     object
# Artist                    object
# top_genre                 object
# Year                       int64
# Beats Per Minute (BPM)     int64
# Energy                     int64
# Danceability               int64
# Loudness (dB)              int64
# Liveness                   int64
# Valence                    int64
# Length (Duration)         object
# Acousticness               int64
# Speechiness                int64
# Popularity                 int64
# dtype: object
# Index                      int64
# Title                     object
# Artist                    object
# top_genre                 object
# Year                       int64
# Beats Per Minute (BPM)     int64
# Energy                     int64
# Danceability               int64
# Loudness (dB)              int64
# Liveness                   int64
# Valence                    int64
# Length (Duration)         object
# Acousticness               int64
# Speechiness                int64
# Popularity                 int64
# dtype: object

# %%
df2.isnull().values.any()
# Out:
# False

# %%
genre_list = df['top_genre'].unique()
print(genre_list)
# Out:
# ['adult standards' 'album rock' 'alternative hip hop' 'alternative metal'
#  'classic rock' 'alternative pop rock' 'pop' 'modern rock'
#  'detroit hip hop' 'alternative rock' 'dutch indie' 'garage rock'
#  'dutch cabaret' 'permanent wave' 'classic uk pop' 'dance pop'
#  'modern folk rock' 'dutch pop' 'dutch americana' 'alternative dance'
#  'german pop' 'afropop' 'british soul' 'irish rock' 'disco' 'big room'
#  'art rock' 'danish pop rock' 'neo mellow' 'britpop' 'boy band'
#  'carnaval limburg' 'arkansas country' 'latin alternative' 'british folk'
#  'celtic' 'chanson' 'celtic rock' 'hip pop' 'east coast hip hop'
#  'dutch rock' 'blues rock' 'electro' 'australian pop' 'belgian rock'
#  'downtempo' 'reggae fusion' 'british invasion' 'finnish metal'
#  'canadian pop' 'bow pop' 'dutch hip hop' 'dutch metal' 'soft rock'
#  'acoustic pop' 'acid jazz' 'dutch prog' 'candy pop' 'operatic pop'
#  'trance' 'scottish singer-songwriter' 'mellow gold' 'alternative pop'
#  'dance rock' 'atl hip hop' 'eurodance' 'blues' 'canadian folk' 'big beat'
#  'art pop' 'uk pop' 'glam metal' 'brill building pop' 'g funk'
#  'happy hardcore' 'belgian pop' 'classic schlager' 'contemporary country'
#  'barbadian pop' 'gabba' 'chamber pop' 'british singer-songwriter'
#  'indie pop' 'australian rock' 'nederpop' 'australian indie folk'
#  'folk-pop' 'electropop' 'edm' 'metropopolis' 'irish pop' 'electronica'
#  'alaska indie' 'irish singer-songwriter' 'stomp and holler'
#  'australian dance' 'australian psych' 'laboratorio'
#  'contemporary vocal jazz' 'rock-and-roll' 'glam rock'
#  'classic soundtrack' 'icelandic indie' 'danish pop'
#  'compositional ambient' 'neo soul' 'streektaal' 'italian pop'
#  'indie anthem-folk' 'la pop' 'baroque pop' 'ccm' 'electro house'
#  'austropop' 'australian americana' 'latin' 'chicago soul' 'classic soul'
#  'bubblegum pop' 'classic country pop' 'europop' 'hard rock' 'reggae'
#  'j-core' 'funk' 'folk' 'punk' 'basshall' 'australian alternative rock'
#  'yacht rock' 'alternative country' 'celtic punk' 'new wave pop'
#  'classic canadian rock' 'christelijk' 'levenslied' 'cyberpunk'
#  'gangster rap' 'diva house' 'classical rock' 'canadian rock'
#  'german pop rock' 'british alternative rock' 'latin jazz'
#  'german alternative rock' 'classic italian pop' 'pop punk' 'motown'
#  'bebop']

# %%
plt.figure(figsize=(14,8))
sns.set_theme(style="white")
corr = df.corr()
heatmap = sns.heatmap(corr, annot=True, cmap="Blues", fmt='.1g')
# Out:
# C:\Users\Harris\AppData\Local\Temp\ipykernel_1336\1386861542.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
# Print variance age data from dataset
sns.barplot(x=df2.top_genre.value_counts()[:30].index,y=df.top_genre.value_counts()[:30].values)
plt.xlabel('Genre')
plt.ylabel('Genre Counter')
plt.title('Genre Analysis System')
plt.rcParams["figure.figsize"] = (15, 20)
plt.rcParams["xtick.labelsize"] = 8
plt.xticks(rotation=90)
plt.show()

# %%
# #add new column 'GenreRange' into dataset and normalize the data
# df2['Genre_Range']=0
# year1_index=df2[(df2.year<=2015)].index 
# year2_index=df2[(df2.year>=2016) & (df2.year<=2018)].index
# year3_index=df2[(df2.year>2018)].index
# for index in year3_index:
#     df2.loc[index,'Genre_Range']=2
    
# for index in year2_index:
#     df2.loc[index,'Genre_Range']=1

# for index in year1_index:
#     df2.loc[index,'Genre_Range']=0

# # Draw a categorical scatterplot to show each observation
# sns.swarmplot(x="Genre_Range", y="year",hue='top_genre',
#                palette=["red", "cyan", "red","red","cyan","red","cyan","red","red","red","red","red","red","cyan","cyan",
#                         "red","red","red","red","red","red","cyan","red","cyan","cyan","red","cyan","cyan","red","red","red",
#                         "red","red","cyan"], data=df2)
# plt.show()

# %% [markdown]
# # GROUPING THE GENRE

# %%
# values = ['canadian contemporary r&b','latin', 'electro house','australian dance','beatlesque','neo soul','brostep','irish singer-songwriter']
# df2 = df2[df2.top_genre.isin(values) == False]
# Change genre into numeric value
df2['genre_class'] = 0
#Maingroup
#Pop Class
# i=1
# while(i<df2.shape[0]):
#     if 'pop' in df2.loc[i,'top_genre']:
#         print('Classified a classic')
#         df2.loc[i,'genre_class']= 0
#     elif 'hip hop' in df2.loc[i,'top_genre']:
#         print('Classified a country')
#         df2.loc[i,'genre_class']= 1
#     elif 'rock' in df2.loc[i,'top_genre']:
#         print('Classified a pop')
#         df2.loc[i,'genre_class'] = 2
#     else:
#         print('Unclassified')
#         df2.loc[i,'genre_class'] = -1
        
#     i+=1

values = ['canadian contemporary r&b','latin', 'electro house','australian dance','beatlesque','neo soul','brostep','irish singer-songwriter']
df2 = df2[df2.top_genre.isin(values) == False]
# Change genre into numeric value
df2['genre_class'] = 0
#Maingroup
#Pop Class
df2.loc[df2.top_genre == 'dance pop','genre_class'] = 0
df2.loc[df2.top_genre == 'pop','genre_class'] = 0
df2.loc[df2.top_genre == 'canadian pop', 'genre_class'] = 0
df2.loc[df2.top_genre == 'electropop', 'genre_class'] = 0
df2.loc[df2.top_genre == 'folk-pop', 'genre_class'] = 0
df2.loc[df2.top_genre == 'danish pop', 'genre_class'] = 0
df2.loc[df2.top_genre == 'acoustic pop', 'genre_class'] = 0
df2.loc[df2.top_genre == 'australian pop', 'genre_class'] = 0
df2.loc[df2.top_genre == 'pop dance','genre_class'] = 0
df2.loc[df2.top_genre == 'boy band', 'genre_class'] = 0
#Rap Class
df2.loc[df2.top_genre == 'dfw rap', 'genre_class'] = 1
df2.loc[df2.top_genre == 'melodic rap', 'genre_class'] = 1
df2.loc[df2.top_genre == 'emo rap','genre_class'] = 1
df2.loc[df2.top_genre == 'rap','genre_class'] = 1
df2.loc[df2.top_genre == 'cali rap', 'genre_class'] = 1
df2.loc[df2.top_genre == 'gangster rap','genre_class'] = 1
df2.loc[df2.top_genre == 'chicago rap', 'genre_class'] = 1
df2.loc[df2.top_genre == 'pop rap', 'genre_class'] = 1
#Rock Class
df2.loc[df2.top_genre == 'modern rock', 'genre_class'] = 2
df2.loc[df2.top_genre == 'alternative rock', 'genre_class'] = 2
#Hip Hop Class
df2.loc[df2.top_genre == 'canadian hip hop', 'genre_class'] = 3 
df2.loc[df2.top_genre == 'north carolina hip hop', 'genre_class'] = 3
df2.loc[df2.top_genre == 'detroit hip hop', 'genre_class'] = 3
df2.loc[df2.top_genre == 'lgbtq+ hip hop','genre_class'] = 3
df2.loc[df2.top_genre == 'conscious hip hop', 'genre_class'] = 3



#Group for all genre
# df2.loc[df2.top_genre == 'dance pop','genre_class'] = 0
# df2.loc[df2.top_genre == 'pop','genre_class'] = 1
# df2.loc[df2.top_genre == 'dfw rap', 'genre_class'] = 2
# df2.loc[df2.top_genre == 'modern rock', 'genre_class'] = 3
# df2.loc[df2.top_genre == 'canadian pop', 'genre_class'] = 4
# df2.loc[df2.top_genre == 'canadian contemporary r&b', 'genre_class'] = 5
# df2.loc[df2.top_genre == 'electropop', 'genre_class'] = 6
# df2.loc[df2.top_genre == 'melodic rap', 'genre_class'] = 7
# df2.loc[df2.top_genre == 'latin', 'genre_class'] = 8
# df2.loc[df2.top_genre == 'folk-pop', 'genre_class'] = 9
# df2.loc[df2.top_genre == 'canadian hip hop', 'genre_class'] = 10
# df2.loc[df2.top_genre == 'emo rap','genre_class'] = 11
# df2.loc[df2.top_genre == 'rap','genre_class'] = 12
# df2.loc[df2.top_genre == 'north carolina hip hop', 'genre_class'] = 13
# df2.loc[df2.top_genre == 'boy band', 'genre_class'] = 14
# df2.loc[df2.top_genre == 'detroit hip hop', 'genre_class'] = 15
# df2.loc[df2.top_genre == 'electro house', 'genre_class'] = 16
# df2.loc[df2.top_genre == 'australian dance', 'genre_class'] = 17
# df2.loc[df2.top_genre == 'beatlesque', 'genre_class'] = 18
# df2.loc[df2.top_genre == 'cali rap', 'genre_class'] = 19
# df2.loc[df2.top_genre == 'danish pop', 'genre_class'] = 20
# df2.loc[df2.top_genre == 'acoustic pop', 'genre_class'] = 21
# df2.loc[df2.top_genre == 'lgbtq+ hip hop','genre_class'] = 22
# df2.loc[df2.top_genre == 'gangster rap','genre_class'] = 23
# df2.loc[df2.top_genre == 'chicago rap', 'genre_class'] = 24
# df2.loc[df2.top_genre == 'australian pop', 'genre_class'] = 25
# df2.loc[df2.top_genre == 'alternative rock', 'genre_class'] = 26
# df2.loc[df2.top_genre == 'conscious hip hop', 'genre_class'] = 27
# df2.loc[df2.top_genre == 'classic rock', 'genre_class'] = 28
# df2.loc[df2.top_genre == 'neo soul', 'genre_class'] = 29
# df2.loc[df2.top_genre == 'pop rap', 'genre_class'] = 30
# df2.loc[df2.top_genre == 'brostep', 'genre_class'] = 31
# df2.loc[df2.top_genre == 'irish singer-songwriter', 'genre_class'] = 32
# df2.loc[df2.top_genre == 'pop dance','genre_class'] = 33


df2.drop(labels=['top_genre'], axis=1)
# Out:
# Classified a pop
# Classified a country
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a country
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a country
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a country
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a country
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a country
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a country
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a country
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a country
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a country
# Classified a classic
# Classified a classic
# Classified a country
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a country
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a country
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a country
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a country
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Classified a country
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a country
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a country
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a country
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Classified a country
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Classified a country
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a country
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a country
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a country
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Classified a country
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Classified a country
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a country
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a country
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Classified a country
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a classic
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Classified a classic
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a classic
# Classified a pop
# Classified a pop
# Classified a classic
# Unclassified
# Classified a pop
# Classified a pop
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Classified a pop
# Classified a pop
# Classified a pop
# Classified a pop
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Unclassified
# Classified a pop
# Unclassified
# Unclassified
#       Index                                  Title                 Artist  \
# 0         1                                Sunrise            Norah Jones
# 1         2                            Black Night            Deep Purple
# 2         3                         Clint Eastwood               Gorillaz
# 4         5                 Waitin' On A Sunny Day      Bruce Springsteen
# 5         6  The Road Ahead (Miles Of The Unknown)           City To City
# ...     ...                                    ...                    ...
# 1981   1982                       Midnight Rambler     The Rolling Stones
# 1982   1983                              Get Ready             Rare Earth
# 1983   1984      Black Magic Woman - 2018 Remaster          Fleetwood Mac
# 1984   1985     Suite: Judy Blue Eyes - Remastered  Crosby, Stills & Nash
# 1991   1992                        Johnny B. Goode            Chuck Berry
#
#       Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 0     2004                     157      30            53            -14
# 1     2000                     135      79            50            -11
# 2     2001                     168      69            66             -9
# 4     2002                     106      82            58             -5
# 5     2004                      99      46            54             -9
# ...    ...                     ...     ...           ...            ...
# 1981  1969                      75      66            40            -10
# 1982  1969                     127      87            41             -6
# 1983  1969                     129      41            46            -11
# 1984  1969                     154      36            45            -13
# 1991  1959                     168      80            53             -9
#
#       Liveness  Valence Length (Duration)  Acousticness  Speechiness  \
# 0           11       68               201            94            3
# 1           17       81               207            17            7
# 2            7       52               341             2           17
# 4           10       87               256             1            3
# 5           14       14               247             0            2
# ...        ...      ...               ...           ...          ...
# 1981        17       51               413            77           12
# 1982        83       65             1,292             0            4
# 1983        28       44               173             5            4
# 1984        20       30               444            47            4
# 1991        31       97               162            74            7
#
#       Popularity  genre_class
# 0             71            0
# 1             39            2
# 2             69            1
# 4             59            2
# 5             45            0
# ...          ...          ...
# 1981          50            2
# 1982          45            2
# 1983          48            2
# 1984          67            2
# 1991          74            2
#
# [1275 rows x 15 columns]

# %%
plt.figure(figsize=(14,14))
sns.set_theme(style="white")
corr = df2.corr()
heatmap = sns.heatmap(corr, annot=True, cmap="Blues", fmt='.1g')
# Out:
# C:\Users\Harris\AppData\Local\Temp\ipykernel_1336\2740095045.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df2.corr()

# %%
# hehv = np.where((df2['genre_class']==0) & (df2['Energy']>=61) & (df2['Valence']>=50))

# print(df2.loc[hehv])

# %%
# # Resets te options
# pd.reset_option('all')
# display(df2)

# %%
df2["Length (Duration)"] = df2["Length (Duration)"].str.replace(',','')
df2["Length (Duration)"] = df2["Length (Duration)"].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1275 entries, 0 to 1991
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1275 non-null   int64
#  1   Title                   1275 non-null   object
#  2   Artist                  1275 non-null   object
#  3   top_genre               1275 non-null   object
#  4   Year                    1275 non-null   int64
#  5   Beats Per Minute (BPM)  1275 non-null   int64
#  6   Energy                  1275 non-null   int64
#  7   Danceability            1275 non-null   int64
#  8   Loudness (dB)           1275 non-null   int64
#  9   Liveness                1275 non-null   int64
#  10  Valence                 1275 non-null   int64
#  11  Length (Duration)       1275 non-null   int32
#  12  Acousticness            1275 non-null   int64
#  13  Speechiness             1275 non-null   int64
#  14  Popularity              1275 non-null   int64
#  15  genre_class             1275 non-null   int64
# dtypes: int32(1), int64(12), object(3)
# memory usage: 164.4+ KB

# %%
genre_list = df2['top_genre'].unique()
print(genre_list)
# Out:
# ['adult standards' 'album rock' 'alternative hip hop' 'classic rock'
#  'alternative pop rock' 'pop' 'modern rock' 'detroit hip hop'
#  'alternative rock' 'garage rock' 'classic uk pop' 'dance pop'
#  'modern folk rock' 'dutch pop' 'german pop' 'afropop' 'irish rock'
#  'art rock' 'danish pop rock' 'britpop' 'celtic rock' 'hip pop'
#  'east coast hip hop' 'dutch rock' 'blues rock' 'australian pop'
#  'belgian rock' 'canadian pop' 'bow pop' 'dutch hip hop' 'soft rock'
#  'acoustic pop' 'candy pop' 'operatic pop' 'alternative pop' 'dance rock'
#  'atl hip hop' 'art pop' 'uk pop' 'brill building pop' 'belgian pop'
#  'barbadian pop' 'chamber pop' 'indie pop' 'australian rock' 'nederpop'
#  'folk-pop' 'electropop' 'metropopolis' 'irish pop' 'rock-and-roll'
#  'glam rock' 'danish pop' 'italian pop' 'la pop' 'baroque pop' 'austropop'
#  'bubblegum pop' 'classic country pop' 'europop' 'hard rock'
#  'australian alternative rock' 'yacht rock' 'new wave pop'
#  'classic canadian rock' 'classical rock' 'canadian rock'
#  'german pop rock' 'british alternative rock' 'german alternative rock'
#  'classic italian pop' 'pop punk']

# %%
df2.genre_class.value_counts()
# Out:
# 2    847
# 0    399
# 1     29
# Name: genre_class, dtype: int64

# %%
df2.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)       Energy  \
# count  1275.000000  1275.000000             1275.000000  1275.000000
# mean   1011.880784  1992.027451              120.394510    61.240000
# std     541.012441    15.793408               27.737933    21.225865
# min       1.000000  1959.000000               37.000000     5.000000
# 25%     565.500000  1978.000000              100.000000    45.000000
# 50%    1033.000000  1991.000000              119.000000    64.000000
# 75%    1451.000000  2006.000000              136.000000    78.000000
# max    1992.000000  2019.000000              206.000000    99.000000
#
#        Danceability  Loudness (dB)     Liveness      Valence  \
# count   1275.000000    1275.000000  1275.000000  1275.000000
# mean      53.545098      -8.912941    18.814118    50.771765
# std       15.164202       3.607003    16.625030    24.882054
# min       10.000000     -27.000000     2.000000     3.000000
# 25%       43.000000     -11.000000     9.000000    30.000000
# 50%       53.000000      -8.000000    12.000000    49.000000
# 75%       65.000000      -6.000000    22.000000    71.500000
# max       95.000000      -2.000000    99.000000    99.000000
#
#        Length (Duration)  Acousticness  Speechiness   Popularity  genre_class
# count        1275.000000   1275.000000  1275.000000  1275.000000  1275.000000
# mean          270.258039     26.419608     5.061176    60.067451     1.351373
# std           102.122145     27.097135     4.569130    13.993613     0.924371
# min           102.000000      0.000000     2.000000    12.000000     0.000000
# 25%           217.000000      4.000000     3.000000    50.000000     0.000000
# 50%           251.000000     17.000000     4.000000    62.000000     2.000000
# 75%           295.000000     43.000000     5.000000    71.000000     2.000000
# max          1412.000000     99.000000    55.000000   100.000000     2.000000

# %% [markdown]
# # SPLIT THE DATASET INTO TRAIN AND TEST SET

# %%
#Splitting data
import sklearn
from sklearn.model_selection import train_test_split

# head of the data
# print(df2.head())

x = df2.iloc[:,5:14]
y = df2.loc[:,'genre_class']
# print(x.shape,y.shape)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=0)
print(np.unique(y_train))
# Out:
# [0 1 2]

# %% [markdown]
# # MODEL & TECHNIQUE AND EVALUATION

# %% [markdown]
# **The models with using accuracy and confusion matrix as the evaluation method**

# %% [markdown]
# **1.Decision Tree**

# %%
import sklearn.metrics as metrics
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
dt = DecisionTreeClassifier(criterion='entropy')
dt.fit(x_train,y_train)
y_predict = dt.predict(x_test)
print(metrics.accuracy_score(y_test,y_predict))
# Out:
# 0.6292428198433421

# %% [markdown]
# **2.SVM**

# %%
# ended up not using

# from sklearn.svm import LinearSVC

# clf = LinearSVC().fit(x_train, y_train)
# print('spotify dataset')
# print('Accuracy of Linear SVC classifier on training set: {:.2f}'
#      .format(clf.score(x_train, y_train)))
# print('Accuracy of Linear SVC classifier on test set: {:.2f}'
#      .format(clf.score(x_test, y_test)))

# %%
svm_linear=SVC(kernel='linear', C=10,gamma=10).fit(x_train, y_train)
svm_linear.score(x_test,y_test)
# Out:
# 0.6475195822454308

# %%
# svm_poly=SVC(kernel='poly', C=1,gamma=1,probability=True).fit(x_train, y_train)
# svm_poly.score(x_test,y_test)

# %%
svm_sigmoid=SVC(kernel='sigmoid', C=2,gamma=3,probability=True).fit(x_train, y_train)
svm_sigmoid.score(x_test,y_test)
# Out:
# 0.6501305483028721

# %% [markdown]
# **3.KNN**

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (0.21.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.1.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.23.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.5.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.9.3)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (3.6.2)
# Requirement already satisfied: setuptools in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (49.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn import datasets, neighbors
from mlxtend.plotting import plot_decision_regions

knn = KNeighborsClassifier(n_neighbors=54)
knn.fit(x_train,y_train)
knn.predict(x_test)
accuracy_score = knn.score(x_test,y_test) 
print("Accuracy score of test is ""{:.3f}".format(accuracy_score))
# Out:
# Accuracy score of test is 0.653

# %%
np.array(y_test)
# Out:
# array([2, 0, 1, 2, 2, 0, 2, 2, 0, 0, 2, 2, 0, 2, 0, 0, 0, 2, 2, 2, 2, 2,
#        0, 2, 0, 2, 0, 2, 2, 2, 2, 2, 0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 0,
#        2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 0, 0, 0, 2, 2, 2, 2, 2, 0, 0, 2, 2,
#        0, 0, 2, 2, 0, 2, 0, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2,
#        0, 2, 2, 0, 0, 2, 0, 2, 2, 0, 0, 2, 0, 2, 2, 2, 2, 2, 0, 2, 2, 2,
#        0, 2, 2, 0, 0, 0, 2, 2, 2, 2, 0, 2, 2, 0, 2, 2, 0, 2, 2, 1, 0, 0,
#        0, 0, 2, 2, 2, 2, 2, 0, 0, 2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 0,
#        2, 2, 2, 0, 0, 2, 2, 2, 0, 0, 2, 2, 2, 0, 2, 2, 0, 0, 2, 2, 2, 0,
#        2, 0, 0, 2, 0, 0, 2, 2, 2, 2, 0, 2, 2, 2, 0, 2, 2, 0, 2, 2, 2, 0,
#        2, 0, 0, 2, 2, 2, 0, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 0, 2, 2, 2, 0, 1, 0, 1, 0, 0, 2, 2,
#        2, 2, 2, 2, 0, 2, 0, 2, 2, 0, 2, 0, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2,
#        2, 1, 0, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 0, 2, 0, 0, 2, 2, 2, 2,
#        2, 0, 2, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 2, 2,
#        2, 0, 0, 0, 2, 2, 0, 2, 2, 0, 2, 0, 2, 2, 2, 2, 2, 0, 2, 2, 2, 0,
#        2, 0, 2, 2, 2, 2, 0, 2, 2, 1, 0, 2, 2, 2, 2, 0, 2, 2, 0, 2, 2, 0,
#        2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 0, 0, 2, 0, 2, 1, 2,
#        0, 0, 0, 2, 2, 2, 2, 2, 0], dtype=int64)

# %%
# #Predict the response for test dataset
# y_pred = svm_poly.predict(x_test)
# y_pred

# %%
y_pred = svm_linear.predict(x_test)
y_pred
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int64)

# %%
y_pred = svm_sigmoid.predict(x_test)
y_pred
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int64)

# %%
y_pred = dt.predict(x_test)
y_pred
# Out:
# array([2, 2, 0, 2, 2, 2, 2, 0, 0, 2, 2, 0, 0, 2, 0, 2, 0, 2, 2, 2, 2, 0,
#        0, 2, 0, 2, 0, 2, 2, 2, 2, 2, 2, 0, 2, 2, 0, 2, 2, 0, 2, 2, 2, 2,
#        2, 0, 0, 0, 2, 0, 2, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 0, 2, 2, 2,
#        2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 2, 0, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 0, 2, 2, 2,
#        2, 2, 2, 0, 2, 2, 0, 2, 0, 2, 2, 2, 2, 2, 0, 1, 0, 0, 1, 1, 0, 2,
#        2, 0, 0, 0, 2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2,
#        2, 2, 0, 0, 0, 2, 2, 2, 0, 2, 2, 0, 2, 0, 2, 0, 2, 2, 0, 2, 0, 2,
#        2, 2, 0, 2, 1, 0, 2, 0, 0, 1, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        0, 2, 0, 2, 2, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#        2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 1, 2, 0, 1, 2, 0, 2, 0, 0, 2,
#        0, 2, 0, 0, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2,
#        2, 0, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 1, 2, 0, 2, 2, 2, 2, 0, 2,
#        2, 0, 2, 2, 2, 2, 0, 0, 2, 0, 2, 0, 2, 2, 2, 0, 0, 2, 0, 0, 2, 2,
#        0, 2, 0, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#        2, 0, 2, 2, 2, 2, 0, 2, 0, 1, 2, 0, 2, 2, 2, 0, 2, 2, 0, 2, 0, 2,
#        2, 0, 0, 2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 2, 1, 0, 0, 2, 0, 0, 2, 2,
#        2, 2, 0, 0, 2, 2, 0, 0, 2], dtype=int64)

# %%
y_pred = knn.predict(x_test)
y_pred
# Out:
# array([2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int64)

# %%
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6527415143603134

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print(metrics.r2_score(y_test, y_pred))
print(metrics.mean_squared_log_error(y_test, y_pred))

plt.figure(figsize=(10,10))
sns.regplot(y_test, y_pred, fit_reg=True, scatter_kws={"s": 100})
# Out:
# -0.5111212411776729
# 0.3919027198926351
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [293], line 8
#       5 print(metrics.mean_squared_log_error(y_test, y_pred))
#       7 plt.figure(figsize=(10,10))
# ----> 8 sns.regplot(y_test, y_pred, fit_reg=True, scatter_kws={"s": 100})
#
# TypeError: regplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 2 keyword-only arguments) were given

# %%
df2.corr()

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))

# %%
cm = confusion_matrix(y_test, y_pred)
 
# plotting confusion matrix
# %matplotlib inline
plt.figure (figsize=(10,7))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %% [markdown]
# # Predict data

# %% [markdown]
# **Predict the genre from dataset**

# %%
df2.loc[[3]]

# %%
x_test

# %%
y_test

# %%
res = dt.predict(x_test.loc[[3]])
res

# %%
res = svm_linear.predict(x_test.loc[[3]])
res

# %%
res = svm_sigmoid.predict(x_test.loc[[3]])
res

# %%
# res = svm_poly.predict(x_test.loc[[3]])
# res

# %%
res = knn.predict(x_test.loc[[3]])
res

# %% [markdown]
# **Predict genre from dummy data**

# %%
column_names = x_test.columns.values.tolist()

# %%
column_names

# %%
data = {
 'beats.per.minute' :[100],
 'energy' :[85],
 'danceability' :[75],
 'loudness.dB' :[-4],
 'liveness' :[9],
 'valance' :[70],
 'length' :[207],
 'acousticness' :[7],
 'speechiness' :[18],
 'popularity' :[86],

}

# %%
df_test = pd.DataFrame(data)

# %%
df_test

# %%
res = dt.predict(df_test)
res

# %%
res = svm_linear.predict(df_test)
res

# %%
res = svm_sigmoid.predict(df_test)
res

# %%
res = svm_poly.predict(df_test)
res

# %%
res = knn.predict(df_test)
res

# %%
data = {
 'beats.per.minute' :[114],
 'energy' :[62],
 'danceability' :[68],
 'loudness.dB' :[-6],
 'liveness' :[17],
 'valance' :[50],
 'length' :[212],
 'acousticness' :[25],
 'speechiness' :[10],
 'popularity' :[80]
}
df_test = pd.DataFrame(data)
df_test

# %%
res = dt.predict(df_test)
res

# %%
res0 = svm_linear.predict(df_test)
res0

# %%
res1 = svm_sigmoid.predict(df_test)
res1

# %%
res2 = svm_poly.predict(df_test)
res2

# %%
res3 = knn.predict(df_test)
res3

# %%
hehv = np.where((df2['energy']>=61) & (df2['valance']>=50))
