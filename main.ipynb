# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (1.1.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (1.23.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\harris\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb

# %%
url = "https://raw.githubusercontent.com/Gitroars/BS_FoDS_Project/main/Dataset/Top_100_most_Streamed_-_Sheet1.csv"
df = pd.read_csv(url)
df.head()
# Out:
#                     title         artist                  top genre  year  \
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
# 4                 Perfect     Ed Sheeran                        pop  2017
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
# 3               110      41            50           -6        11       45
# 4                95      45            60           -6        11       17
#
#    length  acousticness  speechiness  popularity
# 0     200             0            6          91
# 1     174            12            5          88
# 2     141            17            4          88
# 3     182            75            3          86
# 4     263            16            2          86

# %%
#Checking for nulls
print("Nulls")
print("===")
print(df.isnull().sum())
# Out:
# Nulls
# ===
# title               0
# artist              0
# top genre           0
# year                0
# beats.per.minute    0
# energy              0
# danceability        0
# loudness.dB         0
# liveness            0
# valance             0
# length              0
# acousticness        0
# speechiness         0
# popularity          0
# dtype: int64

# %%
#Checking for zeros
print("Nulls")
print("===")
print(df.eq(0).sum())
# Out:
# Nulls
# ===
# title               0
# artist              0
# top genre           0
# year                0
# beats.per.minute    0
# energy              0
# danceability        0
# loudness.dB         0
# liveness            0
# valance             0
# length              0
# acousticness        8
# speechiness         0
# popularity          0
# dtype: int64

# %%
#Check data 
list(df.columns)
# Out:
# ['title',
#  'artist',
#  'top genre',
#  'year',
#  'beats.per.minute',
#  'energy',
#  'danceability',
#  'loudness.dB',
#  'liveness',
#  'valance',
#  'length',
#  'acousticness',
#  'speechiness',
#  'popularity']

# %%
#find correlation
plt.figure(figsize=(12,12))
dataplot = sb.heatmap(df.corr(),cmap="YlGnBu",annot=True, linewidths = .5)
plt.show()
# Out:
#                       year  beats.per.minute    energy  danceability  \
# year              1.000000          0.009033 -0.010494      0.391194
# beats.per.minute  0.009033          1.000000  0.323986      0.104166
# energy           -0.010494          0.323986  1.000000      0.035240
# danceability      0.391194          0.104166  0.035240      1.000000
# loudness.dB       0.091207          0.178862  0.728515      0.108573
# liveness         -0.078568         -0.086662  0.057674      0.013476
# valance           0.183940          0.067254  0.294611      0.475190
# length           -0.514321          0.120206 -0.028618     -0.141803
# acousticness      0.050635         -0.295801 -0.709537     -0.220167
# speechiness       0.155663          0.176701  0.042489      0.044887
# popularity        0.049665         -0.006600 -0.250860     -0.055114
#
#                   loudness.dB  liveness   valance    length  acousticness  \
# year                 0.091207 -0.078568  0.183940 -0.514321      0.050635
# beats.per.minute     0.178862 -0.086662  0.067254  0.120206     -0.295801
# energy               0.728515  0.057674  0.294611 -0.028618     -0.709537
# danceability         0.108573  0.013476  0.475190 -0.141803     -0.220167
# loudness.dB          1.000000  0.110725  0.246607  0.003013     -0.537402
# liveness             0.110725  1.000000 -0.179223 -0.086144     -0.162159
# valance              0.246607 -0.179223  1.000000 -0.134255     -0.176209
# length               0.003013 -0.086144 -0.134255  1.000000     -0.017920
# acousticness        -0.537402 -0.162159 -0.176209 -0.017920      1.000000
# speechiness         -0.233368  0.008842 -0.050402 -0.093814      0.057169
# popularity          -0.065674 -0.090935 -0.075228 -0.009545      0.222251
#
#                   speechiness  popularity
# year                 0.155663    0.049665
# beats.per.minute     0.176701   -0.006600
# energy               0.042489   -0.250860
# danceability         0.044887   -0.055114
# loudness.dB         -0.233368   -0.065674
# liveness             0.008842   -0.090935
# valance             -0.050402   -0.075228
# length              -0.093814   -0.009545
# acousticness         0.057169    0.222251
# speechiness          1.000000   -0.020567
# popularity          -0.020567    1.000000
# C:\Users\Harris\AppData\Local\Temp\ipykernel_17020\3998684134.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.corr())
# C:\Users\Harris\AppData\Local\Temp\ipykernel_17020\3998684134.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sb.heatmap(df.corr(),cmap="YlGnBu",annot=True, linewidths = .5)
